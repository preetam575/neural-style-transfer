# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from keras import backend

import time
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.optimizers import SGD

from scipy.optimize import fmin_l_bfgs_b
tf.compat.v1.disable_eager_execution()

# %%
def preprocess_image(image_path):

    image=Image.open(image_path)
    image=image.resize((512,512))

    img_array=np.asarray(image,dtype='float32')
    img_array=np.expand_dims(img_array,axis=0)


    img_array[:, :, :,0]-=103.939
    img_array[:, :, :,1]-=116.779
    img_array[:, :, :,2]-=123.68
    
    img_array=img_array[:, :, :,::-1]
    return img_array

# %%
def deprocess_image(x):
    x = x.reshape((512, 512, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype("uint8")
    return x

# %%
content_array=preprocess_image('/content/IMG-20230307-WA0001.jpg')
style_array=preprocess_image('/content/starry_night.jpg')

# %%
content_array.shape
# Out:
# (1, 512, 512, 3)

# %%
alpha= 0.025
beta=5.0
gamma=1.00

# %%
content_image = backend.variable(content_array)
style_image = backend.variable(style_array)
final_image = backend.placeholder((1, 512, 512, 3))

# %%
input_tensor=backend.concatenate([content_image,style_image,final_image], axis=0)
loss=backend.variable(0.)
model= VGG16(input_tensor=input_tensor,weights='imagenet',include_top=False)
layers = dict([(layer.name, layer.output) for layer in model.layers])
layers
# Out:
# {'input_2': <tf.Tensor 'concat_1:0' shape=(3, 512, 512, 3) dtype=float32>,
#  'block1_conv1': <tf.Tensor 'block1_conv1_1/Relu:0' shape=(3, 512, 512, 64) dtype=float32>,
#  'block1_conv2': <tf.Tensor 'block1_conv2_1/Relu:0' shape=(3, 512, 512, 64) dtype=float32>,
#  'block1_pool': <tf.Tensor 'block1_pool_1/MaxPool:0' shape=(3, 256, 256, 64) dtype=float32>,
#  'block2_conv1': <tf.Tensor 'block2_conv1_1/Relu:0' shape=(3, 256, 256, 128) dtype=float32>,
#  'block2_conv2': <tf.Tensor 'block2_conv2_1/Relu:0' shape=(3, 256, 256, 128) dtype=float32>,
#  'block2_pool': <tf.Tensor 'block2_pool_1/MaxPool:0' shape=(3, 128, 128, 128) dtype=float32>,
#  'block3_conv1': <tf.Tensor 'block3_conv1_1/Relu:0' shape=(3, 128, 128, 256) dtype=float32>,
#  'block3_conv2': <tf.Tensor 'block3_conv2_1/Relu:0' shape=(3, 128, 128, 256) dtype=float32>,
#  'block3_conv3': <tf.Tensor 'block3_conv3_1/Relu:0' shape=(3, 128, 128, 256) dtype=float32>,
#  'block3_pool': <tf.Tensor 'block3_pool_1/MaxPool:0' shape=(3, 64, 64, 256) dtype=float32>,
#  'block4_conv1': <tf.Tensor 'block4_conv1_1/Relu:0' shape=(3, 64, 64, 512) dtype=float32>,
#  'block4_conv2': <tf.Tensor 'block4_conv2_1/Relu:0' shape=(3, 64, 64, 512) dtype=float32>,
#  'block4_conv3': <tf.Tensor 'block4_conv3_1/Relu:0' shape=(3, 64, 64, 512) dtype=float32>,
#  'block4_pool': <tf.Tensor 'block4_pool_1/MaxPool:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_conv1': <tf.Tensor 'block5_conv1_1/Relu:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_conv2': <tf.Tensor 'block5_conv2_1/Relu:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_conv3': <tf.Tensor 'block5_conv3_1/Relu:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_pool': <tf.Tensor 'block5_pool_1/MaxPool:0' shape=(3, 16, 16, 512) dtype=float32>}

# %%
def content_loss(content,final):
    return backend.sum(backend.square(final-content))

layer_features = layers['block2_conv2']
content_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]

loss = loss + alpha * content_loss(content_image_features,
                                      combination_features)

# %%
def gram_matrix(T):
    features=backend.batch_flatten(backend.permute_dimensions(T, (2,0,1)))
    gram = backend.dot(features,backend.transpose(features))
    return gram

# %%
def style_loss(style,final):
    sty=  gram_matrix(style)
    fin= gram_matrix(final)
    return backend.sum(backend.square(sty-fin))/ (4 * (3**2) * (262144**2))

feature_layers = ['block1_conv2', 'block2_conv2',
                  'block3_conv3', 'block4_conv3',
                  'block5_conv3']
for layer_name in feature_layers:
    layer_features = layers[layer_name]
    style_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_features, combination_features)
    loss = loss +(beta / len(feature_layers)) * sl

# %%
def total_var_loss(T):
    a= backend.square(T[:,:511,:511,:]-T[:,1:,:511,:])
    b= backend.square(T[:,:511,:511,:]-T[:,:511:,1:,:])
    return backend.sum(backend.pow(a+b,1.25))

loss = loss + gamma * total_var_loss(final_image)

# %%
grads = backend.gradients(loss, final_image)

# %%
outputs = [loss]
outputs = outputs + grads
f_outputs = backend.function([final_image], outputs)

# %%
def eval_loss_and_grads(x):
    x = x.reshape((1, 512, 512, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    grad_value = outs[1].flatten().astype('float64')
    return loss_value, grad_value

class Evaluator():
    def __init__(self):
        self.loss_value=None
        self.grad_values=None
    
    def tot_loss(self,T):
        assert self.loss_value is None
        loss_value,grad_values=eval_loss_and_grads(T)
        self.loss_value=loss_value
        self.grad_values= grad_values
        return self.loss_value
    
    def grads(self,T):
        assert self.loss_value is not None
        grad_values=np.copy(self.grad_values)
        self.loss_value=None
        self.grad_values=None
        return grad_values
    
evaluator=Evaluator()

# %%
x = np.random.uniform(0, 255, (1, 512, 512, 3)) - 128.

iterations = 50

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.tot_loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    end_time = time.time()
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 110156095000.0
# Iteration 0 completed in 7s
# Start of iteration 1
# Current loss value: 62480134000.0
# Iteration 1 completed in 8s
# Start of iteration 2
# Current loss value: 49974456000.0
# Iteration 2 completed in 9s
# Start of iteration 3
# Current loss value: 45619060000.0
# Iteration 3 completed in 7s
# Start of iteration 4
# Current loss value: 43488110000.0
# Iteration 4 completed in 8s
# Start of iteration 5
# Current loss value: 42043810000.0
# Iteration 5 completed in 7s
# Start of iteration 6
# Current loss value: 41082360000.0
# Iteration 6 completed in 7s
# Start of iteration 7
# Current loss value: 40440520000.0
# Iteration 7 completed in 8s
# Start of iteration 8
# Current loss value: 39965778000.0
# Iteration 8 completed in 8s
# Start of iteration 9
# Current loss value: 39621964000.0
# Iteration 9 completed in 8s
# Start of iteration 10
# Current loss value: 39365060000.0
# Iteration 10 completed in 7s
# Start of iteration 11
# Current loss value: 39165608000.0
# Iteration 11 completed in 8s
# Start of iteration 12
# Current loss value: 38990852000.0
# Iteration 12 completed in 7s
# Start of iteration 13
# Current loss value: 38834290000.0
# Iteration 13 completed in 7s
# Start of iteration 14
# Current loss value: 38697520000.0
# Iteration 14 completed in 8s
# Start of iteration 15
# Current loss value: 38588740000.0
# Iteration 15 completed in 7s
# Start of iteration 16
# Current loss value: 38499490000.0
# Iteration 16 completed in 7s
# Start of iteration 17
# Current loss value: 38420280000.0
# Iteration 17 completed in 8s
# Start of iteration 18
# Current loss value: 38352343000.0
# Iteration 18 completed in 8s
# Start of iteration 19
# Current loss value: 38299410000.0
# Iteration 19 completed in 7s
# Start of iteration 20
# Current loss value: 38247180000.0
# Iteration 20 completed in 8s
# Start of iteration 21
# Current loss value: 38198230000.0
# Iteration 21 completed in 8s
# Start of iteration 22
# Current loss value: 38159294000.0
# Iteration 22 completed in 7s
# Start of iteration 23
# Current loss value: 38121910000.0
# Iteration 23 completed in 7s
# Start of iteration 24
# Current loss value: 38090863000.0
# Iteration 24 completed in 8s
# Start of iteration 25
# Current loss value: 38061355000.0
# Iteration 25 completed in 7s
# Start of iteration 26
# Current loss value: 38034710000.0
# Iteration 26 completed in 8s
# Start of iteration 27
# Current loss value: 38012637000.0
# Iteration 27 completed in 7s
# Start of iteration 28
# Current loss value: 37988704000.0
# Iteration 28 completed in 8s
# Start of iteration 29
# Current loss value: 37967495000.0
# Iteration 29 completed in 8s
# Start of iteration 30
# Current loss value: 37949964000.0
# Iteration 30 completed in 7s
# Start of iteration 31
# Current loss value: 37934040000.0
# Iteration 31 completed in 8s
# Start of iteration 32
# Current loss value: 37919326000.0
# Iteration 32 completed in 8s
# Start of iteration 33
# Current loss value: 37904370000.0
# Iteration 33 completed in 7s
# Start of iteration 34
# Current loss value: 37890466000.0
# Iteration 34 completed in 8s
# Start of iteration 35
# Current loss value: 37878096000.0
# Iteration 35 completed in 7s
# Start of iteration 36
# Current loss value: 37867143000.0
# Iteration 36 completed in 8s
# Start of iteration 37
# Current loss value: 37855736000.0
# Iteration 37 completed in 8s
# Start of iteration 38
# Current loss value: 37844870000.0
# Iteration 38 completed in 8s
# Start of iteration 39
# Current loss value: 37835182000.0
# Iteration 39 completed in 7s
# Start of iteration 40
# Current loss value: 37826847000.0
# Iteration 40 completed in 8s
# Start of iteration 41
# Current loss value: 37819175000.0
# Iteration 41 completed in 8s
# Start of iteration 42
# Current loss value: 37811690000.0
# Iteration 42 completed in 7s
# Start of iteration 43
# Current loss value: 37805023000.0
# Iteration 43 completed in 8s
# Start of iteration 44
# Current loss value: 37798445000.0
# Iteration 44 completed in 8s
# Start of iteration 45
# Current loss value: 37792612000.0
# Iteration 45 completed in 7s
# Start of iteration 46
# Current loss value: 37787468000.0
# Iteration 46 completed in 8s
# Start of iteration 47
# Current loss value: 37782696000.0
# Iteration 47 completed in 8s
# Start of iteration 48
# Current loss value: 37778227000.0
# Iteration 48 completed in 8s
# Start of iteration 49
# Current loss value: 37773935000.0
# Iteration 49 completed in 7s

# %%
x = np.reshape(x, (512, 512, 3))
Image.fromarray(x, 'RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F40582390A0>

# %%
info
# Out:
# {'grad': array([ 27.95710754,  47.64630127,  35.02383423, ...,  56.98268127,
#         276.13018799, 143.3575592 ]),
#  'task': 'STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT',
#  'funcalls': 21,
#  'nit': 20,
#  'warnflag': 1}

# %%
image = deprocess_image(x)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

imge_out = Image.fromarray(image.astype('uint8'))
img_as_img = imge_out.convert("RGB")
img_as_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F3F32C31F70>

# %%
img_as_img.save('test.png')

# %%
type(x)
# Out:
# numpy.ndarray

# %%
def numpy2pil(np_array: np.ndarray) -> Image:
    """
    Convert an HxWx3 numpy array into an RGB Image
    """

    #assert_msg = 'Input shall be a HxWx3 ndarray'
    assert isinstance(np_array, np.ndarray)
    #assert len(np_array.shape) == 3
    #assert np_array.shape[2] == 3

    img = Image.fromarray(np_array, 'RGB')
    return img


img = numpy2pil(x)
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F3F32C31A00>
